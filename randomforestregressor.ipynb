# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error , r2_score
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('datasets/Housing.csv').sort_values(by="price")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 544   1750000  3850         3          1        2      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 541   1767150  2400         3          1        1       no        no       no
# 540   1820000  3000         2          1        1      yes        no      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 4    11410000  7420         4          1        2      yes       yes      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 2    12250000  9960         3          2        2      yes        no      yes
# 1    12250000  8960         4          4        4      yes        no       no
# 0    13300000  7420         4          2        3      yes        no       no
#
# ...

# %%
data[['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']] = data[['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea']].replace({"yes": 1, "no": 0})
data['furnishingstatus'] = data['furnishingstatus'].replace({'furnished' : 2,'semi-furnished' : 1,'unfurnished' : 0}) 
scaler = MinMaxScaler()
data['area'] = scaler.fit_transform(data[['area']])
# data = pd.DataFrame(scaler.fit_transform(data),columns=data.columns)
data['price'] = scaler.fit_transform(data[['price']])
data
# Out:
#         price      area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 544  0.000000  0.151203         3          1        2         1          0
# 543  0.000000  0.086598         3          1        1         0          0
# 542  0.000000  0.135395         2          1        1         1          0
# 541  0.001485  0.051546         3          1        1         0          0
# 540  0.006061  0.092784         2          1        1         1          0
# ..        ...       ...       ...        ...      ...       ...        ...
# 4    0.836364  0.396564         4          1        2         1          1
# 3    0.906061  0.402062         4          2        2         1          0
# 2    0.909091  0.571134         3          2        2         1          0
# 1    0.909091  0.502405         4          4        4         1          0
# 0    1.000000  0.396564         4          2        3         1          0
#
# ...

# %%
x = data.drop(['price'], axis=1)
y = data['price']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10)

# %%
model = RandomForestRegressor(n_estimators=10)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10)

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R^2 Score: {r2:.2f}')
# Out:
# Mean Squared Error: 0.01
# R^2 Score: 0.57
